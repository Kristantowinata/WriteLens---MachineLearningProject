# %%
from datasets import load_dataset
import warnings
warnings.filterwarnings('ignore')

ds = load_dataset("yaful/MAGE")

# %%
import pandas as pd

# %%
train = pd.DataFrame(ds['train'])

# %%
test = pd.DataFrame(ds['test'])

# %%
print(train.shape)
print(test.shape)
# Out:
# (319071, 3)
# (60743, 3)

# %%
train.to_csv('mage_train.csv')
test.to_csv('mage_test.csv')
